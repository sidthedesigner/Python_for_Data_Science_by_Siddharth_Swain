# %% [markdown]
# ## Python Error Handling
#
# - https://www.programiz.com/python-programming/exceptions
#
# - https://www.geeksforgeeks.org/errors-and-exceptions-in-python/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Practice
#
# Try: This block will test the excepted error to occur
#
# Except:  Here you can handle the error
#
# Else: If there is no exception then this block will be executed
#
# Finally: Finally block always gets executed either exception is generated or not

# %%
print("fsfsfsfsd)
# Out:
#   File "<ipython-input-1-a30f09cebbdd>", line 1
#     print("fsfsfsfsd)
#                      ^
# SyntaxError: EOL while scanning string literal

# %%
def test():
  return 5/0

# %%
test()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-fbd55f77ab7c> in <module>()
# ----> 1 test()
#
# <ipython-input-2-d819d92adf9a> in test()
#       1 def test():
# ----> 2   return 5/0
#
# ZeroDivisionError: division by zero

# %%
a = open("test.txt", 'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-157b76ae4ba1> in <module>()
# ----> 1 a = open("test.txt", 'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
try:
  a = open("test.txt", 'r')
except:
  print("Sorry the text file does not exist in the system.")
# Out:
# Sorry the text file does not exist in the system.

# %%
try:
  a = 5/0
except ArithmeticError:
  print("Sorry the text file does not exist in the system.")
# Out:
# Sorry the text file does not exist in the system.

# %%
try:
  a = 5/0
except IOError:
  print("Sorry the text file does not exist in the system.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-6a4c68d02d5a> in <module>()
#       1 try:
# ----> 2   a = 5/0
#       3 except IOError:
#       4   print("Sorry the text file does not exist in the system.")
#
# ZeroDivisionError: division by zero

# %%
try:
  a = 5/0
except ArithmeticError as e:
  print("Sorry the text file does not exist in the system.",e)
# Out:
# Sorry the text file does not exist in the system. division by zero

# %%
try:
  a = 5/4
except ArithmeticError as e:
  print("Sorry the text file does not exist in the system.",e)
else:
  print("This will execute once try gets executed.")
# Out:
# This will execute once try gets executed.

# %%
try:
  a = 5/0
except ArithmeticError as e:
  print("Sorry the text file does not exist in the system.",e)
else:
  print("This will execute once try gets executed.")
# Out:
# Sorry the text file does not exist in the system. division by zero

# %%
try:
  a = 5/4
except ArithmeticError as e:
  print("Sorry the text file does not exist in the system.",e)
else:
  print("This will execute once try gets executed.")
  f = open("test.txt","r")
# Out:
# This will execute once try gets executed.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-638ad74c6269> in <module>()
#       5 else:
#       6   print("This will execute once try gets executed.")
# ----> 7   f = open("test.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
try:
  a = 5/4
except ArithmeticError as e:
  print("Sorry the text file does not exist in the system.",e)
else:
  print("This will execute once try gets executed.")
  try:
    f = open("test.txt","r")
  except:
    print("There is no file to open.")
# Out:
# This will execute once try gets executed.
# There is no file to open.

# %%
try:
  a = 5/0
except ArithmeticError as e:
  print("Sorry the text file does not exist in the system.",e)
  try:
    f = open("test.txt","r")
  except:
    print("There is no file to open.")
else:
  print("This will execute once try gets executed.")
  try:
    f = open("test.txt","r")
  except:
    print("There is no file to open.")
# Out:
# Sorry the text file does not exist in the system. division by zero
# There is no file to open.

# %% [markdown]
# ## Practice

# %%
try:
  l = [4,5,6,7,8,9]
  l[1]
except:
  print("List out of range error!")
  t = (4,5,6,7,7,8,9)
  print(t)
else:
  t = (4,5,6,7,7,8,9)
  print(t)
# Out:
# (4, 5, 6, 7, 7, 8, 9)

# %%
try:
  l = [4,5,6,7,8,9]
  l[100]
except:
  print("List out of range error!")
  t = (4,5,6,7,7,8,9)
  print(t)
else:
  t = (4,5,6,7,7,8,9)
  print(t)
# Out:
# List out of range error!
# (4, 5, 6, 7, 7, 8, 9)

# %%
try:
  l = [4,5,6,7,8,9]
  l[1]
except:
  print("List out of range error!")
  t = (4,5,6,7,7,8,9)
  print(t)
  try:
    t[0] = "sudh"
  except:
    print("Tuples are immutable!")
else:
  print("There is no issue with this code.")
# Out:
# There is no issue with this code.

# %%
try:
  l = [4,5,6,7,8,9]
  l[10]
except:
  print("List out of range error!")
  t = (4,5,6,7,7,8,9)
  print(t)
  try:
    t[0] = "sudh"
  except:
    print("Tuples are immutable!")
else:
  print("There is no issue with this code.")
# Out:
# List out of range error!
# (4, 5, 6, 7, 7, 8, 9)
# Tuples are immutable!

# %% [markdown]
# ## Practice

# %% [markdown]
# Try: This block will test the excepted error to occur
#
# Except:  Here you can handle the error
#
# Else: If there is no exception then this block will be executed
#
# Finally: Finally block always gets executed either exception is generated or not

# %%
try:
  f = open("new.txt",'r')
except:
  print("No file found!")
finally:
  print("Finally I will execute in any case.")
# Out:
# No file found!
# Finally I will execute in any case.

# %%
try:
  f = open("new.txt",'r')
except:
  print("No file found!")
finally:
  print("Finally I will execute in any case.")
  l = [4,5,6,7]
  try:
    print(l[10])
  except:
    pass
# Out:
# No file found!
# Finally I will execute in any case.

# %%
try:
  f = open("new.txt",'r')
except:
  print("No file found!")
else:
  print("No file found!")
finally:
  print("Finally I will execute in any case.")
# Out:
# No file found!
# Finally I will execute in any case.

# %%
try:
  f = open("test1.txt","r")
except IOerror as e:
  print("this is my error",e)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-d20ca786a7fe> in <module>()
#       1 try:
# ----> 2   f = open("test1.txt","r")
#       3 except IOerror as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test1.txt'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-d20ca786a7fe> in <module>()
#       1 try:
#       2   f = open("test1.txt","r")
# ----> 3 except IOerror as e:
#       4   print("this is my error",e)
#
# NameError: name 'IOerror' is not defined

# %% [markdown]
# ## Practice

# %%
def askforint():
  while True:
    try:
      a = int(input("enter an integer:"))
    except Exception as e:
      print("Please enter a valid input!",e)
    else:
      print("You have entered a valid integer.")
      break

# %%
askforint()
# Out:
# enter an integer:2d
# Please enter a valid input! invalid literal for int() with base 10: '2d'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-80c9c030d41a> in <module>()
# ----> 1 askforint()
#
# <ipython-input-11-fefb1faaa538> in askforint()
#       2   while True:
#       3     try:
# ----> 4       a = int(input("enter an integer:"))
#       5     except Exception as e:
#       6       print("Please enter a valid input!",e)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
def askforint():
  while True:
    try:
      a = int(input("enter an integer:"))
    except Exception as e:
      print("Please enter a valid input!",e)
    else:
      print("You have entered a valid integer.")
      break
    finally:
      print("End of program.")

# %%
askforint()
# Out:
# enter an integer:2
# You have entered a valid integer.
# End of program.

# %%
def askforint():
  while True:
    try:
      a = int(input("enter an integer:"))
      c = 8/a
    except FileNotFoundError as e:
      print("Please enter a valid input!",e)
    except IOError as e:
      print(e)
    except ValueError as e:
      print(e)    
    except ZeroDivisionError as e:
      print(e)
    except Exception as e:
      print("This is coming from parent class",e)  
    except ArithmeticError as e:
      print("This is an arithmetic error",e)
    else:
      print("You have entered a valid integer.")
      break
    finally:
      print("End of program.")

# %%
askforint()
# Out:
# enter an integer:2
# You have entered a valid integer.
# End of program.

# %%
askforint()
# Out:
# enter an integer:st
# invalid literal for int() with base 10: 'st'
# End of program.
# enter an integer:w
# invalid literal for int() with base 10: 'w'
# End of program.
# enter an integer:2
# You have entered a valid integer.
# End of program.

# %% [markdown]
# ## Create Your Exception

# %%
def create_your_exception(a):
    if a == 6:
        raise Exception(a)

# %%
create_your_exception(4)

# %%
create_your_exception(6)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-646dc0bb2e87> in <module>
# ----> 1 create_your_exception(6)
#
# <ipython-input-1-9f85a39da78a> in create_your_exception(a)
#       1 def create_your_exception(a):
#       2     if a == 6:
# ----> 3         raise Exception(a)
#
# Exception: 6

# %%
try:
    create_your_exception(6)
except Exception as e:
    print(e)
# Out:
# 6

# %%
5/6
# Out:
# 0.8333333333333334

# %%
def createexception(a):
  if a == 6:
    raise Exception(a)
  else:
    print("Input is okay.")
  return a

# %%
b = createexception(5)
b
# Out:
# Input is okay.
# 5

# %%
b = createexception(6)
b
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-bf18962dbdfe> in <module>()
# ----> 1 b = createexception(6)
#       2 b
#
# <ipython-input-5-5e00ccabc969> in createexception(a)
#       1 def createexception(a):
#       2   if a == 6:
# ----> 3     raise Exception(a)
#       4   else:
#       5     print("Input is okay.")
#
# Exception: 6

# %%
# Create own exception

def createyourexception(a):
    if a>6:
        raise Exception("Error is: ",a)
    else:
        print("Input is okay.")
    return a

# %%
try:
    createyourexception(10)
except Exception as e:
    print(e)
# Out:
# ('Error is: ', 10)

# %% [markdown]
# ## Question
#
# - Write a program to take input from user and print even numbers from 0 to range.

# %%
def evennum(a):
  for i in range(0,a+1):
    if i % 2 == 0:
      print("The number {} is an even number.".format(i))

# %%
evennum(10)
# Out:
# The number 0 is an even number.
# The number 2 is an even number.
# The number 4 is an even number.
# The number 6 is an even number.
# The number 8 is an even number.
# The number 10 is an even number.

# %%
# Program to take input from user and print even numbers from 0 to range

# Importing all modules
import os

# Changing the directory to module3 (Function to return all even number)
os.chdir("C://Users//Siddharth Swain//Documents//Data//test")

from mod4 import evennum
import logging

# Create log file
logging.basicConfig(filename = "testrun.log" , level = logging.DEBUG , format = '%(asctime)s - %(name)s - %(levelname)s -  %(message)s')

# Create Handlers
console_log = logging.StreamHandler()
console_log.setLevel(logging.DEBUG)
format = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
console_log.setFormatter(format)

# Create a Custom Handler
logging.getLogger('').addHandler(console_log)
logging.info("Start of Program.")
logger = logging.getLogger('Siddharth Swain')

while True:
    try:
        a = int(input("Enter the range limit:"))
        logger.info("Thanks! Your input is valid.")
        evennum(a)
        break
    except Exception as e:
        logger.warning("Sorry, Invalid Input! Please enter an integer as your input.")

logging.info("End of Program.")
# Out:
# 2021-11-08 11:23:41,200 - root - INFO - Start of Program.
# 2021-11-08 11:23:41,200 - root - INFO - Start of Program.
# Enter the range limit:df
# 2021-11-08 11:23:44,986 - Siddharth Swain - WARNING - Sorry, Invalid Input! Please enter an integer as your input.
# 2021-11-08 11:23:44,986 - Siddharth Swain - WARNING - Sorry, Invalid Input! Please enter an integer as your input.
# Enter the range limit:w
# 2021-11-08 11:23:49,619 - Siddharth Swain - WARNING - Sorry, Invalid Input! Please enter an integer as your input.
# 2021-11-08 11:23:49,619 - Siddharth Swain - WARNING - Sorry, Invalid Input! Please enter an integer as your input.
# Enter the range limit:2
# 2021-11-08 11:23:51,651 - Siddharth Swain - INFO - Thanks! Your input is valid.
# 2021-11-08 11:23:51,651 - Siddharth Swain - INFO - Thanks! Your input is valid.
# 2021-11-08 11:23:51,653 - root - INFO - End of Program.
# 2021-11-08 11:23:51,653 - root - INFO - End of Program.
# The number 0 is an even number.
# The number 2 is an even number.
