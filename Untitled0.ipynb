# %% [markdown]
# Hi
#
# ![image.png](data:image/png;base64,...)

# %%
There
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e16fca82da9> in <cell line: 1>()
# ----> 1 There
#       2
#
# NameError: name 'There' is not defined

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# fdfdfdfd
# hjhjhj
