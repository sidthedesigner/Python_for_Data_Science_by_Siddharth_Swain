# %% [markdown]
# # 1. Loops
#
# Python has two primitive loop commands:
#
# - **While Loops**
# - **For Loops**

# %% [markdown]
# # 2. While Loop
#
# With the while loop, we can execute a set of statements as long as a condition is true.
#
# ![image.png](attachment:image.png)
#
# When a while loop is executed, the expression is first evaluated in a Boolean context and if it is true, the loop body is executed. Then the expression is checked again, if it is still true then the body is executed again and this continues until the expression becomes false.

# %%
# Print i as long as i is less than 6.

i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Infinite Loop.

i = 1
while i < 6:
  print(i)
  #i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Note:** remember to increment i, or else the loop will continue forever.
#
# The while loop requires relevant variables to be ready, in this example we need to define an indexing variable, i, which we set to 1.

# %% [markdown]
# # 3. Break Statement
#
# With the break statement, we can stop the loop even if the while condition is true.

# %%
# Exit the loop when i is 3.

i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# # 4. Continue Statement
#
# With the continue statement, we can stop the current iteration, and continue with the next.

# %%
# Continue to the next iteration if i is 3.

i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# # 5. Else Statement
#
# With the else statement we can run a block of code once when the condition no longer is true.

# %%
# Print a message once the condition is false.

i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %% [markdown]
# # Practice

# %%
initial_speed, final_speed = 0 , 100

# It will print my speed is 19, then initial speed updates to 20 and breaks out.

while initial_speed < final_speed:
  print("My speed is {0}.".format(initial_speed))
  initial_speed = initial_speed + 1
  if initial_speed == 20:
    break
# Out:
# My speed is 0.
# My speed is 1.
# My speed is 2.
# My speed is 3.
# My speed is 4.
# My speed is 5.
# My speed is 6.
# My speed is 7.
# My speed is 8.
# My speed is 9.
# My speed is 10.
# My speed is 11.
# My speed is 12.
# My speed is 13.
# My speed is 14.
# My speed is 15.
# My speed is 16.
# My speed is 17.
# My speed is 18.
# My speed is 19.

# %%
a, b = 1 , 10

# It will print my speed is 5, a updates to 6 and condition is true, and print xxxx gets skipped.

while a < b:
  print("My speed is {0}.".format(a))
  a = a + 1
  if a-1 == 5:
    continue
  print("xxxx")
# Out:
# My speed is 1.
# xxxx
# My speed is 2.
# xxxx
# My speed is 3.
# xxxx
# My speed is 4.
# xxxx
# My speed is 5.
# My speed is 6.
# xxxx
# My speed is 7.
# xxxx
# My speed is 8.
# xxxx
# My speed is 9.
# xxxx

# %%
i, j = 1, 5

# Prints till 5 since there is less than or equal to.

while i <= j:
  print(i)
  i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i, j = 1, 5

# Prints till 4 since there is less than.

while i < j:
  print(i)
  i = i + 1
# Out:
# 1
# 2
# 3
# 4

# %%
notes = 5
i = 1

# While finishes execution once 4 is less than 5 and then else block gets executed.

while i < notes:
  print(i)
  i += 1
else:
  print("No 10 Rs. Notes are available!")
# Out:
# 1
# 2
# 3
# 4
# No 10 Rs. Notes are available!

# %%
notes = 5
i = 1
j = 1

# First while block executes till 4 is less than 5 and then control flows to the else block.

# Second while block executes till 3 is less than 4 and then final statement is printed.

while i < notes:
  print(i)
  i += 1
else:
  while j < 4:
    print(j)
    j = j +1
  print("No 10 Rs. Notes are available!")
# Out:
# 1
# 2
# 3
# 4
# 1
# 2
# 3
# No 10 Rs. Notes are available!
